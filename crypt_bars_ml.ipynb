# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df = pd.read_pickle('dataset/cryptbars/binance_BTCUSD_ohlcv_5e6.pkl')

# %%
df = df.reset_index()
df
# Out:
#                      date_time     tick_num      open      high       low  \
# 0      2021-03-01 00:07:03.271       5211.0  45181.79  45446.48  45040.89
# 1      2021-03-01 00:15:12.113      10232.0  45076.30  45600.00  45058.50
# 2      2021-03-01 00:17:21.249      13624.0  45600.00  45987.01  45555.03
# 3      2021-03-01 00:18:12.757      16165.0  45920.41  46317.47  45897.35
# 4      2021-03-01 00:20:29.081      18633.0  46185.31  46354.34  46118.75
# ...                        ...          ...       ...       ...       ...
# 182383 2023-03-10 23:47:18.318  816569522.0  20250.19  20280.00  20249.31
# 182384 2023-03-10 23:49:05.857  816574038.0  20280.00  20298.74  20273.45
# 182385 2023-03-10 23:52:04.136  816578295.0  20284.75  20287.36  20215.08
# 182386 2023-03-10 23:53:02.717  816583011.0  20215.01  20243.02  20158.77
# 182387 2023-03-10 23:56:44.595  816588159.0  20183.01  20210.38  20175.56
#
#            close      volume  cum_ticks  cum_dollar_value  cum_plusticks  \
# ...

# %%
df["vwapret1"]=df.vwap / df.vwap.shift(1)-1
df["vwapret5"]=df.vwap / df.vwap.shift(5)-1
df["vwapret10"]=df.vwap / df.vwap.shift(10)-1
df["vwapret40"]=df.vwap / df.vwap.shift(40)-1
df.vwapret1 = df.vwapret1.shift(-1)
df.vwapret5 = df.vwapret1.shift(-5)
df.vwapret10 = df.vwapret1.shift(-10)
df.vwapret40 = df.vwapret1.shift(-40)
df
# Out:
#                      date_time     tick_num      open      high       low  \
# 0      2021-03-01 00:07:03.271       5211.0  45181.79  45446.48  45040.89
# 1      2021-03-01 00:15:12.113      10232.0  45076.30  45600.00  45058.50
# 2      2021-03-01 00:17:21.249      13624.0  45600.00  45987.01  45555.03
# 3      2021-03-01 00:18:12.757      16165.0  45920.41  46317.47  45897.35
# 4      2021-03-01 00:20:29.081      18633.0  46185.31  46354.34  46118.75
# ...                        ...          ...       ...       ...       ...
# 182383 2023-03-10 23:47:18.318  816569522.0  20250.19  20280.00  20249.31
# 182384 2023-03-10 23:49:05.857  816574038.0  20280.00  20298.74  20273.45
# 182385 2023-03-10 23:52:04.136  816578295.0  20284.75  20287.36  20215.08
# 182386 2023-03-10 23:53:02.717  816583011.0  20215.01  20243.02  20158.77
# 182387 2023-03-10 23:56:44.595  816588159.0  20183.01  20210.38  20175.56
#
#            close      volume  cum_ticks  cum_dollar_value  cum_plusticks  \
# ...

# %%
df.to_pickle('dataset/cryptbars/binance_BTCUSD_ohlcv_5e6_vwapret1-40_for_ns_Transformer.pkl')

# %%
df = pd.read_pickle('dataset/cryptbars/binance_BTCUSD_ohlcv_5e6_vwapret1-40_for_ns_Transformer.pkl')

# %%
df1 = df.drop(['tick_num','optimum_return','t_value_samples','t_value','vwapret5','vwapret10','vwapret40'], axis=1).dropna()
df5 = df.drop(['tick_num','optimum_return','t_value_samples','t_value','vwapret1','vwapret10','vwapret40'], axis=1).dropna()
df10 = df.drop(['tick_num','optimum_return','t_value_samples','t_value','vwapret1','vwapret5','vwapret40'], axis=1).dropna()
df40 = df.drop(['tick_num','optimum_return','t_value_samples','t_value','vwapret1','vwapret5','vwapret10'], axis=1).dropna()

# %%
df1[df1.vwapret1==-0.0703566]
# Out:
# Empty DataFrame
# ...

# %%
df1.to_pickle('dataset/cryptbars/binance_BTCUSD_ohlcv_5e6_vwapret1_for_ns_Transformer.pkl')
df5.to_pickle('dataset/cryptbars/binance_BTCUSD_ohlcv_5e6_vwapret5_for_ns_Transformer.pkl')
df10.to_pickle('dataset/cryptbars/binance_BTCUSD_ohlcv_5e6_vwapret10_for_ns_Transformer.pkl')
df40.to_pickle('dataset/cryptbars/binance_BTCUSD_ohlcv_5e6_vwapret40_for_ns_Transformer.pkl')

# %%
df.to_pickle('dataset/cryptbars/binance_BTCUSD_ohlcv_5e6_noTval_for_ns_Transformer.pkl')

# %%
metrics_vwapret1 = np.load('results/binance_ohlcv_5e6_fixed_emb_vwaprep1_16x16_ns_Transformer_custom_ftMS_sl12_ll6_pl1_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_pred_vwaprep1_hidden16x16_0/metrics.npy')
pred_vwapret1 = np.load('results/binance_ohlcv_5e6_fixed_emb_vwaprep1_16x16_ns_Transformer_custom_ftMS_sl12_ll6_pl1_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_pred_vwaprep1_hidden16x16_0/pred.npy')
truth_vwapret1 = np.load('results/binance_ohlcv_5e6_fixed_emb_vwaprep1_16x16_ns_Transformer_custom_ftMS_sl12_ll6_pl1_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_pred_vwaprep1_hidden16x16_0/true.npy')

# %%
df1
# Out:
#                      date_time      open      high       low     close  \
# 0      2021-03-01 00:07:03.271  45181.79  45446.48  45040.89  45074.91
# 1      2021-03-01 00:15:12.113  45076.30  45600.00  45058.50  45600.00
# 2      2021-03-01 00:17:21.249  45600.00  45987.01  45555.03  45920.33
# 3      2021-03-01 00:18:12.757  45920.41  46317.47  45897.35  46184.42
# 4      2021-03-01 00:20:29.081  46185.31  46354.34  46118.75  46354.34
# ...                        ...       ...       ...       ...       ...
# 182382 2023-03-10 23:44:19.974  20249.57  20257.29  20220.01  20249.71
# 182383 2023-03-10 23:47:18.318  20250.19  20280.00  20249.31  20280.00
# 182384 2023-03-10 23:49:05.857  20280.00  20298.74  20273.45  20284.75
# 182385 2023-03-10 23:52:04.136  20284.75  20287.36  20215.08  20215.08
# 182386 2023-03-10 23:53:02.717  20215.01  20243.02  20158.77  20181.52
#
#             volume  cum_ticks  cum_dollar_value  cum_plusticks  \
# ...

# %%
metrics_vwapret1
# Out:
# array([2.6475513e-01, 1.2409179e-01, 3.5226664e-01, 1.8425868e+00,
#        7.1320343e+02], dtype=float32)

# %%
pred_vwapret1
# Out:
# array([[[0.08413422]],
#
#        [[0.11205392]],
#
#        [[0.11190587]],
#
#        ...,
#
#        [[0.00425813]],
#
#        [[0.1129168 ]],
#
#        [[0.01438035]]], dtype=float32)

# %%
truth_vwapret1
# Out:
# array([[[-0.0703566 ]],
#
#        [[ 0.1709601 ]],
#
#        [[ 0.50250435]],
#
#        ...,
#
#        [[ 0.18743275]],
#
#        [[-0.09523859]],
#
#        [[ 0.6883193 ]]], dtype=float32)

# %%
np.corrcoef(pred_vwapret1.reshape(1,-1)[0], truth_vwapret1.reshape(1,-1)[0])
# Out:
# array([[1.        , 0.17336812],
#        [0.17336812, 1.        ]])

# %%
np.sum(np.where(np.sign(pred_vwapret1.reshape(1,-1)[0])==np.sign(truth_vwapret1.reshape(1,-1)[0]), 1, 0)) / len(pred)
# Out:
# 0.5582748024582967

# %%
metrics_vwapret1_2 = np.load('results/binance_ohlcv_5e6_fixed_emb_vwaprep1_32x16_ns_Transformer_custom_ftMS_sl48_ll12_pl12_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_pred_vwaprep1_hidden32x16_0/metrics.npy')
pred_vwapret1_2 = np.load('results/binance_ohlcv_5e6_fixed_emb_vwaprep1_32x16_ns_Transformer_custom_ftMS_sl48_ll12_pl12_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_pred_vwaprep1_hidden32x16_0/pred.npy')
truth_vwapret1_2 = np.load('results/binance_ohlcv_5e6_fixed_emb_vwaprep1_32x16_ns_Transformer_custom_ftMS_sl48_ll12_pl12_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_pred_vwaprep1_hidden32x16_0/true.npy')

# %%
metrics_vwapret1_2
# Out:
# array([ 0.27007622,  0.12897225,  0.35912707,  1.3223655 , 49.135155  ],
#       dtype=float32)

# %%
truth_vwapret1_2.reshape(1,-1)
# Out:
# array([[-0.0703566 ,  0.1709601 ,  0.50250435, ...,  0.6982575 ,
#          0.7470103 , -0.5356249 ]], dtype=float32)

# %%
pred_vwapret1_2.reshape(1,-1)
# Out:
# array([[-0.02840573, -0.02946038, -0.02918602, ..., -0.00156442,
#         -0.00187682, -0.00145053]], dtype=float32)

# %%
np.corrcoef(np.sign(pred_vwapret1_2.reshape(1,-1)[0]), np.sign(truth_vwapret1_2.reshape(1,-1)[0]))
# Out:
# array([[ 1.        , -0.00124104],
#        [-0.00124104,  1.        ]])

# %%
np.sum(np.where(np.sign(pred_vwapret1_2.reshape(1,-1)[0])==np.sign(truth_vwapret1_2.reshape(1,-1)[0]), 1, 0)) / len(truth_vwapret1_2)
# Out:
# 5.986062335381914

# %%
metrics2 = np.load('results/binance_ohlcv_5e6_fixed_emb_32x16_ns_Transformer_custom_ftMS_sl12_ll6_pl1_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_pred1_hidden32x16_0//metrics.npy')

# %%
pred2 = np.load('results/binance_ohlcv_5e6_fixed_emb_32x16_ns_Transformer_custom_ftMS_sl12_ll6_pl1_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_pred1_hidden32x16_0/pred.npy')

# %%
truth2 = np.load('results/binance_ohlcv_5e6_fixed_emb_32x16_ns_Transformer_custom_ftMS_sl12_ll6_pl1_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_pred1_hidden32x16_0/true.npy')

# %%
metrics2
# Out:
# array([0.39042503, 0.3151853 , 0.56141365, 0.5742356 , 0.78303003],
#       dtype=float32)

# %%
np.corrcoef(np.sign(pred2.reshape(1,-1)[0]), np.sign(truth2.reshape(1,-1)[0]))
# Out:
# array([[1.        , 0.70627965],
#        [0.70627965, 1.        ]])

# %%
np.corrcoef(pred2.reshape(1,-1)[0], truth2.reshape(1,-1)[0])
# Out:
# array([[1.        , 0.82453894],
#        [0.82453894, 1.        ]])

# %%
np.sum(np.where(np.sign(pred2.reshape(1,-1)[0])==np.sign(truth2.reshape(1,-1)[0]), 1, 0)) / len(pred2)
# Out:
# 0.8531606672519754

# %%
metrics3 = np.load('results/binance_ohlcv_5e6_fixed_emb_16x16_ns_Transformer_custom_ftMS_sl12_ll6_pl1_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_pred1_hidden16x16_0/metrics.npy')
pred3 = np.load('results/binance_ohlcv_5e6_fixed_emb_16x16_ns_Transformer_custom_ftMS_sl12_ll6_pl1_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_pred1_hidden16x16_0/pred.npy')
truth3 = np.load('results/binance_ohlcv_5e6_fixed_emb_16x16_ns_Transformer_custom_ftMS_sl12_ll6_pl1_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_pred1_hidden16x16_0/true.npy')

# %%
metrics3
# Out:
# array([0.40133268, 0.33364454, 0.57761973, 0.5941947 , 0.8252417 ],
#       dtype=float32)

# %%
np.corrcoef(pred3.reshape(1,-1)[0], truth3.reshape(1,-1)[0])
# Out:
# array([[1.        , 0.80949123],
#        [0.80949123, 1.        ]])

# %%
np.sum(np.where(np.sign(pred3.reshape(1,-1)[0])==np.sign(truth3.reshape(1,-1)[0]), 1, 0)) / len(pred2)
# Out:
# 0.8323639157155399

# %%
np.sign(pred3.reshape(1,-1)[0])>0 & np.sign(truth3.reshape(1,-1)[0])>0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 np.sign(pred3.reshape(1,-1)[0])>0 & np.sign(truth3.reshape(1,-1)[0])>0
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
np.sum(np.where((np.sign(pred3.reshape(1,-1)[0])>0) & (np.sign(truth3.reshape(1,-1)[0])>0), 1, 0)) / np.sum(np.where(np.sign(pred3.reshape(1,-1)[0])==np.sign(truth3.reshape(1,-1)[0]), 1, 0))
# Out:
# 0.5124266596347815

# %%
np.sum(np.where((np.sign(pred3.reshape(1,-1)[0])<0) & (np.sign(truth3.reshape(1,-1)[0])<0), 1, 0)) / np.sum(np.where(np.sign(pred3.reshape(1,-1)[0])==np.sign(truth3.reshape(1,-1)[0]), 1, 0))
# Out:
# 0.48757334036521854

# %%
df_tval = pd.read_pickle('dataset/cryptbars/binance_BTCUSD_ohlcv_5e6_for_ns_Transformer.pkl')

# %%
df_tval
# Out:
#                      date_time      open      high       low     close  \
# 0      2021-03-01 00:07:03.271  45181.79  45446.48  45040.89  45074.91
# 1      2021-03-01 00:15:12.113  45076.30  45600.00  45058.50  45600.00
# 2      2021-03-01 00:17:21.249  45600.00  45987.01  45555.03  45920.33
# 3      2021-03-01 00:18:12.757  45920.41  46317.47  45897.35  46184.42
# 4      2021-03-01 00:20:29.081  46185.31  46354.34  46118.75  46354.34
# ...                        ...       ...       ...       ...       ...
# 182354 2023-03-10 22:18:15.839  20141.74  20147.93  20125.00  20125.00
# 182355 2023-03-10 22:20:05.146  20125.00  20145.67  20100.31  20145.67
# 182356 2023-03-10 22:22:56.751  20145.97  20150.00  20112.23  20123.72
# 182357 2023-03-10 22:26:14.032  20123.71  20150.57  20115.01  20124.96
# 182358 2023-03-10 22:28:26.174  20124.96  20184.97  20121.86  20179.06
#
#             volume  cum_ticks  cum_dollar_value  cum_plusticks  \
# ...

# %%
metrics_tval = np.load('results/binance_ohlcv_5e6_fixed_emb_tval_32x32_ns_Transformer_custom_ftMT_sl48_ll24_pl1_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_tval_masked_hidden32x32_t_value_0/metrics.npy')
pred_tval =np.load('results/binance_ohlcv_5e6_fixed_emb_tval_32x32_ns_Transformer_custom_ftMT_sl48_ll24_pl1_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_tval_masked_hidden32x32_t_value_0/pred.npy')
truth_tval = np.load('results/binance_ohlcv_5e6_fixed_emb_tval_32x32_ns_Transformer_custom_ftMT_sl48_ll24_pl1_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_tval_masked_hidden32x32_t_value_0/true.npy')

# %%
metrics_tval
# Out:
# array([0.70684236, 0.71983576, 0.84843135, 0.8750577 , 1.0303044 ],
#       dtype=float32)

# %%
np.corrcoef(pred_tval.reshape(1,-1)[0], truth_tval.reshape(1,-1)[0])
# Out:
# array([[1.        , 0.49403571],
#        [0.49403571, 1.        ]])

# %%
np.sum(np.where(np.sign(pred_tval.reshape(1,-1)[0])==np.sign(truth_tval.reshape(1,-1)[0]), 1, 0)) / len(truth_tval)
# Out:
# 0.6726843722563652

# %%
metrics_tval2 = np.load('results/binance_ohlcv_5e6_fixed_emb_tval_32x16_ns_Transformer_custom_ftMT_sl48_ll24_pl1_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_tval_masked_hidden32x16_t_value_0/metrics.npy')
pred_tval2 =np.load('results/binance_ohlcv_5e6_fixed_emb_tval_32x16_ns_Transformer_custom_ftMT_sl48_ll24_pl1_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_tval_masked_hidden32x16_t_value_0/pred.npy')
truth_tval2 = np.load('results/binance_ohlcv_5e6_fixed_emb_tval_32x16_ns_Transformer_custom_ftMT_sl48_ll24_pl1_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_tval_masked_hidden32x16_t_value_0/true.npy')

# %%
metrics_tval2
# Out:
# array([0.7003933, 0.7186808, 0.8477504, 0.8691002, 1.0325114],
#       dtype=float32)

# %%
np.corrcoef(pred_tval2.reshape(1,-1)[0], truth_tval2.reshape(1,-1)[0])
# Out:
# array([[1.        , 0.49693393],
#        [0.49693393, 1.        ]])

# %%
np.sum(np.where(np.sign(pred_tval2.reshape(1,-1)[0])==np.sign(truth_tval2.reshape(1,-1)[0]), 1, 0)) / len(truth_tval2)
# Out:
# 0.6723551360842844

# %%
metrics_tval3 = np.load('results/binance_ohlcv_5e6_fixed_emb_tval_16x16_ns_Transformer_custom_ftMT_sl48_ll24_pl1_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_tval_masked_hidden16x16_t_value_0/metrics.npy')
pred_tval3 =np.load('results/binance_ohlcv_5e6_fixed_emb_tval_16x16_ns_Transformer_custom_ftMT_sl48_ll24_pl1_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_tval_masked_hidden16x16_t_value_0/pred.npy')
truth_tval3 = np.load('results/binance_ohlcv_5e6_fixed_emb_tval_16x16_ns_Transformer_custom_ftMT_sl48_ll24_pl1_dm512_nh8_el2_dl1_df2048_fc3_ebfixed_dtTrue_Fixed_emb_binanceBTCUSD_bars_tval_masked_hidden16x16_t_value_0/true.npy')

# %%
metrics_tval3
# Out:
# array([0.7146727 , 0.7552007 , 0.86902285, 0.8919586 , 1.1173385 ],
#       dtype=float32)

# %%
np.corrcoef(pred_tval3.reshape(1,-1)[0], truth_tval3.reshape(1,-1)[0])
# Out:
# array([[1.       , 0.4436079],
#        [0.4436079, 1.       ]])
